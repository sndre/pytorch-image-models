# %% [markdown]
# # Connect to Drive

# %%
# This mounts your Google Drive to the Colab VM.
from google.colab import drive
drive.mount('/content/drive')

# TODO: Enter the foldername in your Drive where you have saved the unzipped
# assignment folder, e.g. 'colab/cs231n/assignments/assignment3/'
FOLDERNAME = 'colab/pytorch-image-models/'
assert FOLDERNAME is not None, "[!] Enter the foldername."

# Now that we've mounted your Drive, this ensures that
# the Python interpreter of the Colab VM can load
# python files from within it.
import sys
sys.path.append('/content/drive/My Drive/{}'.format(FOLDERNAME))

# %cd /content/drive/My\ Drive/$FOLDERNAME
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/colab/pytorch-image-models

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# !python --version
# Out:
# Python 3.10.12

# %% [markdown]
# # Validate Google ViT Model

# %%
# !pip install -e .
# !pip install ml_collections
# !pip install coremltools

# %%
# !python validate.py datasets/imagenet1k/val --model vit_base_patch16_224.orig_in21k_ft_in1k --workers 2 --pretrained --use-random-sampler --max-batches-for-pca 29 --sparsity 0 --convert-sliced-model-to-coreml
# Out:
# scikit-learn version 1.2.2 is not supported. Minimum required version: 0.17. Maximum required version: 1.1.2. Disabling scikit-learn conversion API.
# XGBoost version 2.0.3 has not been tested with coremltools. You may run into unexpected errors. XGBoost 1.4.2 is the most recent version that has been tested.
# 2024-04-24 06:09:46.422361: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-24 06:09:46.422410: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-24 06:09:46.423734: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python validate.py datasets/imagenet1k/val --model vit_base_patch16_224.orig_in21k_ft_in1k --workers 2 --pretrained --use-random-sampler --max-batches-for-pca 29 --sparsity 20 --convert-sliced-model-to-coreml
# Out:
# scikit-learn version 1.2.2 is not supported. Minimum required version: 0.17. Maximum required version: 1.1.2. Disabling scikit-learn conversion API.
# XGBoost version 2.0.3 has not been tested with coremltools. You may run into unexpected errors. XGBoost 1.4.2 is the most recent version that has been tested.
# 2024-04-25 03:05:48.937496: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-25 03:05:48.937551: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-25 03:05:49.058292: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python validate.py datasets/imagenet1k/val --model vit_base_patch16_224.orig_in21k_ft_in1k --workers 2 --pretrained --use-random-sampler --max-batches-for-pca 29 --sparsity 25 --convert-sliced-model-to-coreml
# Out:
# scikit-learn version 1.2.2 is not supported. Minimum required version: 0.17. Maximum required version: 1.1.2. Disabling scikit-learn conversion API.
# XGBoost version 2.0.3 has not been tested with coremltools. You may run into unexpected errors. XGBoost 1.4.2 is the most recent version that has been tested.
# 2024-04-25 10:31:52.098785: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-25 10:31:52.098857: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-25 10:31:52.188985: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python validate.py datasets/imagenet1k/val --model vit_base_patch16_224.orig_in21k_ft_in1k --workers 2 --pretrained --use-random-sampler --max-batches-for-pca 29 --sparsity 30 --convert-sliced-model-to-coreml
# Out:
# scikit-learn version 1.2.2 is not supported. Minimum required version: 0.17. Maximum required version: 1.1.2. Disabling scikit-learn conversion API.
# XGBoost version 2.0.3 has not been tested with coremltools. You may run into unexpected errors. XGBoost 1.4.2 is the most recent version that has been tested.
# 2024-04-25 10:46:33.270035: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-25 10:46:33.270088: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-25 10:46:33.277087: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python validate.py datasets/imagenet1k/val --model vit_large_patch32_384.orig_in21k_ft_in1k --workers 2 --pretrained --use-random-sampler --max-batches-for-pca 29 --sparsity 0 --convert-sliced-model-to-coreml
# Out:
# scikit-learn version 1.2.2 is not supported. Minimum required version: 0.17. Maximum required version: 1.1.2. Disabling scikit-learn conversion API.
# XGBoost version 2.0.3 has not been tested with coremltools. You may run into unexpected errors. XGBoost 1.4.2 is the most recent version that has been tested.
# 2024-04-29 04:14:46.117823: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-29 04:14:46.117876: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-29 04:14:46.213203: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python validate.py datasets/imagenet1k/val --model vit_large_patch32_384.orig_in21k_ft_in1k --workers 2 --pretrained --use-random-sampler --max-batches-for-pca 29 --sparsity 20 --convert-sliced-model-to-coreml
# Out:
# Streaming output truncated to the last 5000 lines.
# Converting op 393 : sum
# Converting op 394 : constant
# Converting op variance.21 : div
# Converting op 396 : constant
# Converting op 397 : add
# Converting op 398 : rsqrt
# Converting op x.71 : mul
# Converting op x.73 : to
# Converting op 403 : size
# Converting op 404 : size
# Converting op 407 : linear
# Converting op 408 : listconstruct
# Converting op 409 : reshape
# Converting op 410 : listconstruct
# Converting op qkv.11 : permute
# Converting op 412 : unbind
# Converting op q.11 : listunpack
# Converting op x.75 : scaled_dot_product_attention
# Converting op 417 : transpose
# Converting op 418 : listconstruct
# Converting op input.75 : reshape
# Converting op input.77 : linear
# Converting op 423 : dropout
# Setting pytorch op: dropout to no-op.
# Converting op x.77 : add
# Converting op residual.23 : matmul
# Converting op 426 : pow
# Converting op 427 : listconstruct
# Converting op 428 : sum
# ...

# %%
# !python validate.py datasets/imagenet1k/val --model vit_large_patch32_384.orig_in21k_ft_in1k --workers 2 --pretrained --use-random-sampler --max-batches-for-pca 29 --sparsity 25 --convert-sliced-model-to-coreml
# Out:
# Streaming output truncated to the last 5000 lines.
# Converting op 391 : pow
# Converting op 392 : listconstruct
# Converting op 393 : sum
# Converting op 394 : constant
# Converting op variance.21 : div
# Converting op 396 : constant
# Converting op 397 : add
# Converting op 398 : rsqrt
# Converting op x.71 : mul
# Converting op x.73 : to
# Converting op 403 : size
# Converting op 404 : size
# Converting op 407 : linear
# Converting op 408 : listconstruct
# Converting op 409 : reshape
# Converting op 410 : listconstruct
# Converting op qkv.11 : permute
# Converting op 412 : unbind
# Converting op q.11 : listunpack
# Converting op x.75 : scaled_dot_product_attention
# Converting op 417 : transpose
# Converting op 418 : listconstruct
# Converting op input.75 : reshape
# Converting op input.77 : linear
# Converting op 423 : dropout
# Setting pytorch op: dropout to no-op.
# Converting op x.77 : add
# Converting op residual.23 : matmul
# Converting op 426 : pow
# ...

# %%
# !python validate.py datasets/imagenet1k/val --model vit_large_patch32_384.orig_in21k_ft_in1k --workers 2 --pretrained --use-random-sampler --max-batches-for-pca 29 --sparsity 30 --convert-sliced-model-to-coreml
# Out:
# Streaming output truncated to the last 5000 lines.
# Converting op 391 : pow
# Converting op 392 : listconstruct
# Converting op 393 : sum
# Converting op 394 : constant
# Converting op variance.21 : div
# Converting op 396 : constant
# Converting op 397 : add
# Converting op 398 : rsqrt
# Converting op x.71 : mul
# Converting op x.73 : to
# Converting op 403 : size
# Converting op 404 : size
# Converting op 407 : linear
# Converting op 408 : listconstruct
# Converting op 409 : reshape
# Converting op 410 : listconstruct
# Converting op qkv.11 : permute
# Converting op 412 : unbind
# Converting op q.11 : listunpack
# Converting op x.75 : scaled_dot_product_attention
# Converting op 417 : transpose
# Converting op 418 : listconstruct
# Converting op input.75 : reshape
# Converting op input.77 : linear
# Converting op 423 : dropout
# Setting pytorch op: dropout to no-op.
# Converting op x.77 : add
# Converting op residual.23 : matmul
# Converting op 426 : pow
# ...
